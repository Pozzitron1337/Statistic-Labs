# %%
import numpy as np
import scipy.stats as st

# %% [markdown]
# <b>Завдання 1</b>. Перевірка гіпотези однорідності.

# %% [markdown]
# <p><b>A</b>. Критерій пустих блоків. Генеруємо дві незалежні вибірки:</p>
# <p>X=(x_1,...,x_n) ~ F_{ksi}(u)=1-e^{-u},u>=0;</p>
# <p>Y=(y_1,...,y_m) ~ F_{eta}=1-e^{1.1*u},u>=0.</p>
# <p>За допомогою критерію пустих блоків перевірити гіпотезу однорідності при наступних значеннях параметрів:</p>
# <p>а)n=500,m=1000 ; b)n=5000,m=10000 ; с)n=50000,m=100000 .</p>

# %%
def blank_boxes(x,y):
    n=len(x)
    m=len(y)
    p=m/n
    z = st.norm.ppf(1-0.05)
    criteria=n/(1+p)+np.sqrt(n)*z*p/((1+p)**(3/2))
    x_sorted=np.sort(x)
    a=0
    if len(y[y<x_sorted[0]]) == 0:
        a+=1
    for i in range(len(x_sorted)-1):
        if len(y[(x_sorted[i]<y) & (y<x_sorted[i+1])]) == 0:
            a+=1
    if len(y[y>x_sorted[n-1]]) == 0:
        a+=1
        
    print(f'приблизні значення x_sort: {x_sorted[0:3]}')
    print(f'n = {n}')
    print(f'm = {m}')
    print(f'p = {p}')
    print(f'z = {z}')
    print(f'criteria = {criteria}')
    print(f'Кількість блоків alpha = {a}')
    if a<criteria:
        print(f'Статистичні дані не суперечать гіпотезі H_0\n')
    else: 
        print(f'Слід прийняти альтернативну гіпотезу H_1\n')
    
    
def taskA():
    l_x=1
    l_y=1.1
    x=np.random.exponential(scale=1/l_x,size=500)
    y=np.random.exponential(scale=1/l_y,size=1000)
    blank_boxes(x,y)
    x=np.random.exponential(scale=1/l_x,size=5000)
    y=np.random.exponential(scale=1/l_y,size=10000)
    blank_boxes(x,y)
    x=np.random.exponential(scale=1/l_x,size=50000)
    y=np.random.exponential(scale=1/l_y,size=100000)
    blank_boxes(x,y)
taskA()
# Out:
# приблизні значення x_sort: [0.00637283 0.0066006  0.00678196]
# n = 500
# m = 1000
# p = 2.0
# z = 1.6448536269514722
# criteria = 180.8233126758487
# Кількість блоків alpha = 160
# Статистичні дані не суперечать гіпотезі H_0
#
# приблизні значення x_sort: [9.18775892e-05 1.55697744e-04 4.40199753e-04]
# n = 5000
# m = 10000
# p = 2.0
# z = 1.6448536269514722
# criteria = 1711.433912084415
# Кількість блоків alpha = 1670
# Статистичні дані не суперечать гіпотезі H_0
#
# приблизні значення x_sort: [5.17835461e-05 5.45803978e-05 5.94105629e-05]
# n = 50000
# m = 100000
# p = 2.0
# z = 1.6448536269514722
# criteria = 16808.23312675849
# Кількість блоків alpha = 16659
# Статистичні дані не суперечать гіпотезі H_0

# %% [markdown]
# <p><b>В</b>. Критерій X^2. Генеруємо три серії незалежних спостережень:</p>
# <p>X=(x_1,...,x_n) ~ F_{ksi}(u)=1-e^{-u},u>=0;</p>
# <p>Y=(y_1,...,y_m) ~ F_{eta}=1-e^{-u},u>=0.</p>
# <p>Z=(z_1,...,z_k) ~ F_{dzeta}=1-e^{-1.1*u},u>=0</p>
# <p>За допомогою критерію X^2 перевірити гіпотезу однорідності при наступних значеннях параметрів:</p>
# <p>а)n=200,m=600,k=400;</p>
# <p>b)n=2000,m=6000,k=4000;</p>
# <p>с)n=20000,m=60000,k=40000 .</p>
# <b>Зауваження.</b> Кількість  проміжків і самі проміжки  обирати самостійно.

# %%
def select_max(selection):
    maximum=selection[0][0]
    for array in selection:
        temp_max = np.max(array)
        if temp_max > maximum:
            maximum=temp_max
    return maximum

def form_v(selection,U):
    r=len(U)
    k=len(selection)
    v=np.zeros((k,r))
    i=0
    for array in selection:
        for j in range(r-1):
            v[i][j]=len(array[(U[j]<array)&(array<=U[j+1])])
        i+=1
    return v  
    

def chi2(selection,g,r):
    print(f'\nr = {r}')
    k=len(selection)
    maximum = select_max(selection)
    U = np.linspace(0, maximum, r) 
    v=form_v(selection,U)
    v_j=[0]*r
    for j in range(r):
        for i in range(k):
            v_j[j]+=v[i][j]
    
    n_i=[0]*len(selection)
    for i in range(k):
        n_i[i]=len(selection[i])
    n=np.sum(n_i)
    
    sum=0.0
    for i in range(k):
        for j in range(r):
            if v_j[j] != 0.0:
                sum+=(v[i][j]-(n_i[i]*v_j[j])/n)**2
                sum/=(n_i[i]*v_j[j])
    delta=n*(sum)
    z = st.chi2.ppf(1-g,(r-1)*(k-1))
    print(f'Максимальне значення в вибірці: {maximum}')
    print(f'U = {U[0:4]}')
    print(f'v = \n{v}')
    print(f'v_j = {v_j}')
    print(f'n_i = {n_i}')
    print(f'n = {n}')
    print(f'delta = {delta}')
    print(f'z = {z}')
    if delta < z:
        print(f'Статистичні дані не суперечать гіпотезі H_0\n')
    else: 
        print(f'Слід прийняти альтернативну гіпотезу H_1\n')


def taskB():
    l_x=1
    l_y=1
    l_z=1.1
    gamma=0.05
    r=11
    x=np.random.exponential(scale=1/l_x,size=200)
    y=np.random.exponential(scale=1/l_y,size=600)
    z=np.random.exponential(scale=1/l_z,size=400)
    selection=np.array([x,y,z])
    chi2(selection,gamma,r)
    
    x=np.random.exponential(scale=1/l_x,size=2000)
    y=np.random.exponential(scale=1/l_y,size=6000)
    z=np.random.exponential(scale=1/l_z,size=4000)
    selection=np.array([x,y,z])
    chi2(selection,gamma,r)
    
    x=np.random.exponential(scale=1/l_x,size=20000)
    y=np.random.exponential(scale=1/l_y,size=60000)
    z=np.random.exponential(scale=1/l_z,size=40000)
    selection=np.array([x,y,z])
    chi2(selection,gamma,r)
        
taskB()
# Out:
# r = 11
# Максимальне значення в вибірці: 6.992565991867883
# U = [0.        0.6992566 1.3985132 2.0977698]
# v =
# [[ 96.  49.  28.  15.   6.   3.   2.   1.   0.   0.   0.]
#  [310. 138.  77.  32.  13.  18.   5.   3.   2.   2.   0.]
#  [216.  92.  54.  25.  10.   3.   0.   0.   0.   0.   0.]]
# v_j = [622.0, 279.0, 159.0, 72.0, 29.0, 24.0, 7.0, 4.0, 2.0, 2.0, 0.0]
# n_i = [200, 600, 400]
# n = 1200
# delta = 0.667502085613069
# z = 31.410432844230918
# Статистичні дані не суперечать гіпотезі H_0
#
#
# r = 11
# Максимальне значення в вибірці: 9.461216230338726
# U = [0.         0.94612162 1.89224325 2.83836487]
# v =
# [[1.222e+03 4.590e+02 1.980e+02 7.900e+01 2.900e+01 9.000e+00 3.000e+00
#   1.000e+00 0.000e+00 0.000e+00 0.000e+00]
#  [3.670e+03 1.394e+03 5.510e+02 2.400e+02 7.900e+01 4.300e+01 1.000e+01
#   1.000e+01 2.000e+00 1.000e+00 0.000e+00]
#  [2.579e+03 9.060e+02 3.330e+02 1.200e+02 4.000e+01 1.300e+01 3.000e+00
#   3.000e+00 1.000e+00 2.000e+00 0.000e+00]]
# v_j = [7471.0, 2759.0, 1082.0, 439.0, 148.0, 65.0, 16.0, 14.0, 3.0, 3.0, 0.0]
# n_i = [2000, 6000, 4000]
# n = 12000
# delta = 1.0000000041337245
# z = 31.410432844230918
# Статистичні дані не суперечать гіпотезі H_0
#
#
# r = 11
# Максимальне значення в вибірці: 10.708232481913232
# U = [0.         1.07082325 2.1416465  3.21246974]
# v =
# [[1.3058e+04 4.5590e+03 1.5280e+03 5.8000e+02 1.8400e+02 5.3000e+01
#   2.9000e+01 8.0000e+00 1.0000e+00 0.0000e+00 0.0000e+00]
#  [3.9678e+04 1.3293e+04 4.6210e+03 1.6330e+03 5.2800e+02 1.6100e+02
#   5.3000e+01 2.4000e+01 7.0000e+00 2.0000e+00 0.0000e+00]
#  [2.7649e+04 8.5200e+03 2.6870e+03 7.9000e+02 2.4500e+02 7.9000e+01
#   2.6000e+01 3.0000e+00 1.0000e+00 0.0000e+00 0.0000e+00]]
# v_j = [80385.0, 26372.0, 8836.0, 3003.0, 957.0, 293.0, 108.0, 35.0, 9.0, 2.0, 0.0]
# n_i = [20000, 60000, 40000]
# n = 120000
# delta = 0.6666833335568783
# z = 31.410432844230918
# Статистичні дані не суперечать гіпотезі H_0

# %% [markdown]
# <b>Завдання 2</b>. Перевірка гіпотези незалежності.
# <p>Генеруємо вибірку (X,Y) за наступним правилом:
# {x_i} - це реалізації рівномірно розподіленої на [0,1]
# випадкової величини ksi, а {y_i} - це реалізації випадкової величини ksi+eta, де eta має рівномірний розподіл на проміжку [-1,1], тобто (x_i,y_i)=(ksi_i,ksi_i+eta_i)</p>

# %% [markdown]
# <b>А. Критерій X^2.</b>
# <p>Перевірити гіпотезу незалежності за допомогою критерія Х^2 при наступних значеннях параметра n:</p>
# <p> а) n=500 ; b) n=5000 ; с) n=50000</p>
# <p>Зауваження. Значення r та k, а також самі проміжки U_i,i=1,...r та V_j,j=1,...,k обирати самостійно.</p>

# %%
def chi2_independence(X,Y,r,k,g):
    n=len(X)
    X_max=np.max(X)
    Y_max=np.max(Y)
    X_min=np.min(X)
    Y_min=np.min(Y)
    U_X=np.linspace(0,1,r)
    U_Y=np.linspace(-1,2,k)
    v=np.zeros((r-1,k-1))
    for i in range(r-1):
        for j in range(k-1):
            X_temp = X[(U_X[i] < X) & (X <= U_X[i+1])]
            Y_temp = Y[(U_Y[j] < Y) & (Y <= U_Y[j+1])]
            v[i][j] = len(X_temp) + len(Y_temp)
    v_i=np.zeros(r-1)#r=5
    v_j=np.zeros(k-1)#k=10
    for i in range(r-1):
        for j in range(k-1):
            v_i[i]+=v[i][j]
    for j in range(k-1):
        for i in range(r-1):
            v_j[j]+=v[i][j]
    sum=0.0
    for i in range(r-1):
        for j in range(k-1):
            sum+=(v[i][j]-(v_i[i]*v_j[j]/n))**2
            sum/=(v_i[i]*v_j[j])
    delta=n*sum
    z = st.chi2.ppf(1-g,(r-1)*(k-1))
    print(f'U_X: {U_X}')
    print(f'U_Y: {U_Y}')
    print(f'v:\n ={v}')
    print(f'v_i: {v_i}')
    print(f'v_j: {v_j}')
    print(f'delta = {delta}')
    print(f'z = {z}')
    if delta < z:
        print(f'Статистичні дані не суперечать гіпотезі H_0\n')
    else: 
        print(f'Слід прийняти альтернативну гіпотезу H_1\n')
    
    

def taskA():
    g=0.05
    n=500
    r=6
    k=10
    
    ksi=np.random.uniform(low=0.0,high=1.0,size=n)
    eta=np.random.uniform(low=-1.0,high=1.0,size=n)
    X=ksi
    Y=ksi+eta
    chi2_independence(X,Y,r,k,g)
    
    n=5000
    ksi=np.random.uniform(low=0.0,high=1.0,size=n)
    eta=np.random.uniform(low=-1.0,high=1.0,size=n)
    X=ksi
    Y=ksi+eta
    chi2_independence(X,Y,r,k,g)
    
    n=50000
    ksi=np.random.uniform(low=0.0,high=1.0,size=n)
    eta=np.random.uniform(low=-1.0,high=1.0,size=n)
    X=ksi
    Y=ksi+eta
    chi2_independence(X,Y,r,k,g)
    
taskA()
# Out:
# U_X: [0.  0.2 0.4 0.6 0.8 1. ]
# U_Y: [-1.         -0.66666667 -0.33333333  0.          0.33333333  0.66666667
#   1.          1.33333333  1.66666667  2.        ]
# v:
#  =[[112. 136. 172. 190. 181. 180. 170. 149. 119.]
#  [ 94. 118. 154. 172. 163. 162. 152. 131. 101.]
#  [111. 135. 171. 189. 180. 179. 169. 148. 118.]
#  [122. 146. 182. 200. 191. 190. 180. 159. 129.]
#  [116. 140. 176. 194. 185. 184. 174. 153. 123.]]
# v_i: [1409. 1247. 1400. 1499. 1445.]
# v_j: [555. 675. 855. 945. 900. 895. 845. 740. 590.]
# delta = 1467.9749557772748
# z = 61.65623337627955
# Слід прийняти альтернативну гіпотезу H_1
#
# U_X: [0.  0.2 0.4 0.6 0.8 1. ]
# U_Y: [-1.         -0.66666667 -0.33333333  0.          0.33333333  0.66666667
#   1.          1.33333333  1.66666667  2.        ]
# v:
#  =[[1099. 1402. 1679. 1792. 1770. 1831. 1705. 1418. 1124.]
#  [1101. 1404. 1681. 1794. 1772. 1833. 1707. 1420. 1126.]
#  [1121. 1424. 1701. 1814. 1792. 1853. 1727. 1440. 1146.]
#  [1151. 1454. 1731. 1844. 1822. 1883. 1757. 1470. 1176.]
#  [1123. 1426. 1703. 1816. 1794. 1855. 1729. 1442. 1148.]]
# v_i: [13820. 13838. 14018. 14288. 14036.]
# v_j: [5595. 7110. 8495. 9060. 8950. 9255. 8625. 7190. 5720.]
# delta = 13843.259878345661
# z = 61.65623337627955
# Слід прийняти альтернативну гіпотезу H_1
#
# U_X: [0.  0.2 0.4 0.6 0.8 1. ]
# U_Y: [-1.         -0.66666667 -0.33333333  0.          0.33333333  0.66666667
#   1.          1.33333333  1.66666667  2.        ]
# v:
#  =[[11426. 14238. 17016. 18341. 18335. 18239. 17003. 14230. 11388.]
#  [11363. 14175. 16953. 18278. 18272. 18176. 16940. 14167. 11325.]
#  [11392. 14204. 16982. 18307. 18301. 18205. 16969. 14196. 11354.]
#  [11451. 14263. 17041. 18366. 18360. 18264. 17028. 14255. 11413.]
#  [11378. 14190. 16968. 18293. 18287. 18191. 16955. 14182. 11340.]]
# v_i: [140216. 139649. 139910. 140441. 139784.]
# v_j: [57010. 71070. 84960. 91585. 91555. 91075. 84895. 71030. 56820.]
# delta = 136980.0759583047
# z = 61.65623337627955
# Слід прийняти альтернативну гіпотезу H_1

# %% [markdown]
# <b>В. Критерій Спірмена.</b>
# <p>Перевірити гіпотезу незалежності за допомогою критерія Спірмена при наступних значеннях параметра n</p>
#
# <p>а) n=500 ; b) n=5000 ; с) n=50000</p>

# %%
def spearman(X,Y):
    n=len(X)
    X_sort = np.sort(X)
    Y_sort = np.sort(Y)
    R = np.array([np.where(X_sort == x)[0][0] + 1 for x in X])
    S = np.array([np.where(Y_sort == y)[0][0] + 1 for y in Y])
    p=1 - 6/(n*(n**2-1))*np.sum((R - S)**2)
    z = st.norm.ppf(1-0.05/2)
    criteria = z/np.sqrt(n)
    print(f'X_sort: {X_sort[0:4]}')
    print(f'Y_sort: {Y_sort[0:4]}')
    print(f'p = {p}')
    print(f'z = {z}')
    print(f'criteria = {criteria}')
    if np.abs(p)<criteria:
        print(f'Статистичні дані не суперечать гіпотезі H_0\n')
    else:
        print(f'Слід прийняти альтернативну гіпотезу H_1\n')
    
def taskB():
    n=500
    ksi=np.random.uniform(low=0.0,high=1.0,size=n)
    eta=np.random.uniform(low=-1.0,high=1.0,size=n)
    X=ksi
    Y=ksi+eta
    spearman(X,Y)
    
    n=5000
    ksi=np.random.uniform(low=0.0,high=1.0,size=n)
    eta=np.random.uniform(low=-1.0,high=1.0,size=n)
    X=ksi
    Y=ksi+eta
    spearman(X,Y)
    
    n=50000
    ksi=np.random.uniform(low=0.0,high=1.0,size=n)
    eta=np.random.uniform(low=-1.0,high=1.0,size=n)
    X=ksi
    Y=ksi+eta
    spearman(X,Y)
    
taskB()
# Out:
# X_sort: [0.0063021  0.01126143 0.0137129  0.01560608]
# Y_sort: [-0.91795179 -0.86769424 -0.86441855 -0.81588494]
# p = 0.38240754563018253
# z = 1.959963984540054
# criteria = 0.08765225405765815
# Слід прийняти альтернативну гіпотезу H_1
#
# X_sort: [3.28362999e-05 1.67130969e-04 3.30443330e-04 3.66659689e-04]
# Y_sort: [-0.98535573 -0.97437722 -0.94488933 -0.94488655]
# p = 0.393776199271048
# z = 1.959963984540054
# criteria = 0.027718076486993554
# Слід прийняти альтернативну гіпотезу H_1
#
# X_sort: [2.30978090e-05 3.20365133e-05 5.99879636e-05 9.74757177e-05]
# Y_sort: [-0.99265719 -0.98788737 -0.98442881 -0.97715018]
# p = 0.4160741302903337
# z = 1.959963984540054
# criteria = 0.008765225405765815
# Слід прийняти альтернативну гіпотезу H_1

# %% [markdown]
# <b>С. Критерій Кендалла.</b>
# <p>Перевірити гіпотезу незалежності за допомогою критерія Кендалла при наступних значеннях параметра n<p>
# <p>а) n=500 ; b) n=5000 ; с) n=50000</p>

# %%
def kendall(X,Y):
    n=len(X)
    X_sort = np.sort(X)
    Y_sort = np.sort(Y)
    R = np.array([np.where(X_sort == x)[0][0] + 1 for x in X])
    S = np.array([np.where(Y_sort == y)[0][0] + 1 for y in Y])
    pairs=sorted(list(zip(R,S)),key=lambda x: x[0])
    V=np.array(list(zip(*pairs))[1])
    N=0
    for i in range(n):
        subV=V[i+1:]
        N+=len(subV[V[i-1]<subV])
        
    tau=(4*N)/(n*(n-1))-1
    z=st.norm.ppf(1-0.05/2)
    criteria=2*z/(3*np.sqrt(n))
    
    print(f'R: {R[0:4]}')
    print(f'S: {S[0:4]}')
    print(f'pairs = {pairs[0:4]}')
    print(f'V: {V[0:4]}')
    print(f'N = {N}')
    print(f'z = {z}')
    print(f'criteria = {criteria}')
    
    if np.abs(tau)<criteria:
        print(f'Статистичні дані не суперечать гіпотезі H_0\n')
    else:
        print(f'Слід прийняти альтернативну гіпотезу H_1\n')
    
    
    
    
    
def taskC():
    n=500
    ksi=np.random.uniform(low=0.0,high=1.0,size=n)
    eta=np.random.uniform(low=-1.0,high=1.0,size=n)
    X=ksi
    Y=ksi+eta
    kendall(X,Y)
    
    n=5000
    ksi=np.random.uniform(low=0.0,high=1.0,size=n)
    eta=np.random.uniform(low=-1.0,high=1.0,size=n)
    X=ksi
    Y=ksi+eta
    kendall(X,Y)
    
    n=50000
    ksi=np.random.uniform(low=0.0,high=1.0,size=n)
    eta=np.random.uniform(low=-1.0,high=1.0,size=n)
    X=ksi
    Y=ksi+eta
    kendall(X,Y)
    
taskC()
# Out:
# R: [ 19   1 402 324]
# S: [  6 312 394 122]
# pairs = [(1, 312), (2, 231), (3, 29), (4, 96)]
# V: [312 231  29  96]
# N = 82827
# z = 1.959963984540054
# criteria = 0.05843483603843876
# Слід прийняти альтернативну гіпотезу H_1
#
# R: [ 633 4621 4258 4597]
# S: [ 121 4579 4929 2169]
# pairs = [(1, 1112), (2, 2131), (3, 2953), (4, 678)]
# V: [1112 2131 2953  678]
# N = 7982198
# z = 1.959963984540054
# criteria = 0.018478717657995705
# Слід прийняти альтернативну гіпотезу H_1
#
# R: [23493  3230 40645 10066]
# S: [32100 29719 28619 29602]
# pairs = [(1, 2149), (2, 1701), (3, 13582), (4, 15181)]
# V: [ 2149  1701 13582 15181]
# N = 806001677
# z = 1.959963984540054
# criteria = 0.005843483603843878
# Слід прийняти альтернативну гіпотезу H_1

# %% [markdown]
# <b>Завдання 3</b>. Перевірка гіпотези випадковості.
# <p>Припустимо, що вибірка X=(x_1,...,x_n) утворюється за наступним правилом:</p>
# <p>X_i=ksi_1+..._ksi_i, i=1,...,n,
# де {ksi_i} - це послідовність незалежних рівномірно
# розподілених на [-1,1] випадкових величин.</p>
# <p>Перевірити гіпотезу випадковості за допомогою критерію, що ґрунтується на
# обчисленні кількості інверсій при наступних значеннях параметра n:</p>
#
# <p>а) n=500 ; b) n=5000 ; с) n=50000</p>

# %%
def form_X(n):
    ksi=np.random.uniform(low=-1.0,high=1.0,size=n)
    X=np.zeros(n)
    temp=ksi[0]
    X[0]=temp
    for i in range(1,n):
        temp+=ksi[i]
        X[i]=temp
    return X

def calc_eta(X):
    n=len(X)
    eta=np.zeros(n)
    for i in range(n):
        subX=X[i+1:n]
        eta[i]=len(subX[X[i]>subX])
    return eta

def independence(X):
    n=len(X)
    eta=calc_eta(X)
    S=np.sum(eta)
    z=st.norm.ppf((1-0.05)/2)
    criteria=(6/(n**(3/2)))*(S-((n*(n-1))/4))
    print(f'n = {n}')
    print(f'Приблизні значення вибірки Х: {X[0:4]}')
    print(f'eta: {eta[0:4]}')
    print(f'S(X) = {S}')
    print(f'criteria =  {criteria}')
    print(f'z = {z}')
    if criteria<z:
        print(f'Статистичні дані не суперечать гіпотезі H_0\n')
    else: 
        print(f'Слід прийняти альтернативну гіпотезу H_1\n')


def task():
    n=500
    X=form_X(n)
    independence(X)
    
    n=5000
    X=form_X(n)
    independence(X)
    
    n=50000
    X=form_X(n)
    independence(X)
    
task()
# Out:
# n = 500
# Приблизні значення вибірки Х: [-0.13555165 -0.441256    0.47073902  0.71043961]
# eta: [1. 0. 2. 3.]
# S(X) = 15171.0
# criteria =  -25.332324674376018
# z = -0.06270677794321385
# Статистичні дані не суперечать гіпотезі H_0
#
# n = 5000
# Приблизні значення вибірки Х: [ 0.23809939 -0.22206619  0.74991774 -0.08331603]
# eta: [109.  66. 158.  76.]
# S(X) = 6232462.0
# criteria =  -0.2764165260471957
# z = -0.06270677794321385
# Статистичні дані не суперечать гіпотезі H_0
#
# n = 50000
# Приблизні значення вибірки Х: [-0.54379841 -0.80778781 -1.48521975 -1.51668687]
# eta: [49852. 49845. 49814. 49810.]
# S(X) = 861320625.0
# criteria =  126.82966388038919
# z = -0.06270677794321385
# Слід прийняти альтернативну гіпотезу H_1
